# %%
import requests
import json
    

# Sends automated invites to follow a page 

def dispatch_emails():
    """ Dispatches Quora Space follow invites to users in the quora_users.xlsx file.  """
    FILE_NAME = "quora_users.xlsx"  # TODO: This needs to be an object variable 
    
    # TODO: Open file, loop through each user, and sleep for 1-5 minutes every 20 requests
    
    
    return list_of_urls


# Send and invite given the user id
def send_invite(user_id: str, message_string: str = None):
    """ 
    Sends an invite with the message_string to the quora user_id. 
        Sleeps after every 20 requests (60-300 second sleeps -> 400-1200 invites hourly)
    """
    if not message_string:
        message_string = "I’m inviting you to follow The Shopify Space. As a follower, you’ll receive personalized updates on content from the Space."
        
    print("This is the user_id", user_id)
    url = "https://theshopifyspace.quora.com/graphql/gql_POST?q=TribeInviteMessageModal_tribeInviteUsersAndContactsToPermissionLevel_Mutation"
    payload = {
      "queryName": "TribeInviteMessageModal_tribeInviteUsersAndContactsToPermissionLevel_Mutation",
      "variables": {
        "tribeId": 6672205,  # TODO: Quora Space ID? 
        "permission": "follower",  # TODO: Can we edit this? 
        "inviteSource": "tribe_info_header",
        "inviteAllFollowers": False,  # TODO: Conduct research 
        "inviteAllContacts": False,  # TODO: COnduct research 
        "searchList": [
          int(user_id)
        ],
        "followerList": [],
        "emailsOnQuora": [],
        "emailsNotOnQuora": [],
        "emailsMixed": [],
        "customMsg": message_string,
        "emailsFromCsv": [],
        "inviteAllCsv": False,
        "forSubscription": None
      },
      "extensions": {
        "hash": "33b7e952592c458439ba18d5d1113b71ef958468d7c2f30e30267a47d750be63"
      }
    }

    # TODO: Which variables do I need to change? 
    headers = {
      'accept': '*/*',
      'accept-language': 'en-US,en;q=0.9',
      'content-type': 'application/json',
      'cookie': 'm-b=X19j5pKZE12MmP7prBIlxw==; m-s=JDk4N_vAWAc5eHyeM16qEQ==; m-b_lax=X19j5pKZE12MmP7prBIlxw==; m-b_strict=X19j5pKZE12MmP7prBIlxw==; m-dynamicFontSize=regular; m-themeStrategy=auto; m-theme=dark; m-login=1; m-lat=IH1TB/T3WmWvtmllaYJ4v5FNQlWduIUr7R3z6gHjaw==; m-uid=228910367; m-sa=1; _sharedid=028536c1-05eb-4537-af98-91406b5c460b; m-screen_size=898x925; __stripe_mid=e6744f6e-c350-474c-b7ca-2672580cf2a141370f; __stripe_sid=84e7b166-eadc-4422-8e62-e7a4ee84409c9f306f; cto_bundle=7mPZ619OZFF4VDBMSFA4UkpjeUFEWVM4eERjRVloSkhoZjh0SGZRODE2NTc0MiUyQjclMkZrTDRrUE9KNmxnVUY4cDJVNWZMUUNkdExjckE1WnVwdTBVbTRVT0RKR3olMkJ6WkliMWMwbFFxQ1V5Z1FrZmxEbDJoa2NBeDJ3U1NHZlk5ckVoJTJGR3FGS2FXelBzNWxmeCUyRkclMkZFblBIV3gyN0ElM0QlM0Q; cto_bidid=1ZrEiV9NMjVqczhWWTgyJTJCdWZ5ZHdMWmtza2JrOEdIaTBUSnJuSGZyMSUyQno4VUY4elZ2M1JCbWF6dnMwSXlCTVp0eHclMkI5TElUcW1CQ2xPejJpZUlyR2lTSDhLT2JQZDR2ZFR2cmtHTlR2Zzl3TjFWbyUzRA; __gads=ID=d7cb2003ef5dbc53:T=1726607503:RT=1726886540:S=ALNI_MbpPM530aE6nsqkBt_BCj2tQRLffw; __gpi=UID=00000a5156d1dff9:T=1726607503:RT=1726886540:S=ALNI_Mb1ZZBOLlvcgjEJph4RuCbyQUBrCQ; __eoi=ID=e3e25dc29ecd984e:T=1726607503:RT=1726886540:S=AA-AfjYKRqYV5vTPYDH1aql785hY; m-b=X19j5pKZE12MmP7prBIlxw==; m-b_lax=X19j5pKZE12MmP7prBIlxw==; m-b_strict=X19j5pKZE12MmP7prBIlxw==; m-login=1; m-s=JDk4N_vAWAc5eHyeM16qEQ==; m-uid=228910367',
      'origin': 'https://theshopifyspace.quora.com',
      'priority': 'u=1, i',
      'quora-broadcast-id': 'main-w-chan64-8888-react_bcvrophffuppkdpz-6a5Z',
      'quora-canary-revision': 'false',
      'quora-formkey': '70f70e719f28a1fb89ee3c1014bc2b35',
      'quora-page-creation-time': '1726886794874465',
      'quora-revision': 'd86d3c1dd294a83ba55b2fda78e2016b1c3b0f5a',
      'quora-window-id': 'react_bcvrophffuppkdpz',
      'referer': 'https://theshopifyspace.quora.com/',
      'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
      'sec-ch-ua-mobile': '?1',
      'sec-ch-ua-platform': '"Android"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Mobile Safari/537.36'
    }
    
    response = requests.request("POST", url, headers=headers, json=payload)
    
    print(response.text)


send_invite("12233")
# Out:
# This is the user_id 12233

# %%
import shlex
import subprocess
import json 
import pandas as pd



def scrape_users(quora_space_url):
    """ Scrapes all user ids for the given quora space. """
    # Paginates through all the followers 
    # TODO: Change the url, and tribeId (Where do we get the tribeId from?)
    # TODO: Paginate through all users
    # TODO: Create one excel file for all quora users that we pulled 
    # TODO: Sleeps every 5 requests  
    print("This is the url", quora_space_url)

    index = 0
    limit = 3  # TODO: Number of followers / 10 (We fetch 10 account per request) 
    is_valid_operation = True
    data_to_return = []
    
    while is_valid_operation:
        curl_command = """ curl --location 'https://shopifyexpert1.quora.com/graphql/gql_para_POST?q=TribeFollowersSocialFirstPagedListQuery' \
        --header 'accept: */*' \
        --header 'accept-language: en-US,en;q=0.9' \
        --header 'content-type: application/json' \
        --header 'cookie: m-b=X19j5pKZE12MmP7prBIlxw==; m-s=JDk4N_vAWAc5eHyeM16qEQ==; m-b_lax=X19j5pKZE12MmP7prBIlxw==; m-b_strict=X19j5pKZE12MmP7prBIlxw==; m-dynamicFontSize=regular; m-themeStrategy=auto; m-theme=dark; m-login=1; m-lat=IH1TB/T3WmWvtmllaYJ4v5FNQlWduIUr7R3z6gHjaw==; m-uid=228910367; m-sa=1; __stripe_mid=3e07c1bc-9fb4-4951-a2a3-f96eb1680188359660; _sharedid=028536c1-05eb-4537-af98-91406b5c460b; m-screen_size=866x925; __gads=ID=d7cb2003ef5dbc53:T=1726607503:RT=1727149989:S=ALNI_MbpPM530aE6nsqkBt_BCj2tQRLffw; __gpi=UID=00000a5156d1dff9:T=1726607503:RT=1727149989:S=ALNI_Mb1ZZBOLlvcgjEJph4RuCbyQUBrCQ; __eoi=ID=e3e25dc29ecd984e:T=1726607503:RT=1727149989:S=AA-AfjYKRqYV5vTPYDH1aql785hY; cto_bundle=tS-; cto_bidid=0z9ohF9NMjVqczhWWTgyJTJCdWZ5ZHdMWmtza2JrOEdIaTBUSnJuSGZyMSUyQno4VUY4elZ2M1JCbWF6dnMwSXlCTVp0eHclMkI5eHc2ZmdrNzBld1ZhcTlGdDFsdllsUHBPVDVGQW5vMXZOR0I1eEhTaVVSTnpNbDhzdVAxRlMyRkl4eFdqU01QcWRSJTJCb1p0dk1IaXpjV0xWeDA5VTBydyUzRCUzRA; __stripe_sid=80290498-ece6-43dc-9906-b452f4ca8114092ef8' \
        --header 'origin: https://shopifyexpert1.quora.com' \
        --header 'priority: u=1, i' \
        --header 'quora-broadcast-id: main-w-chan65-8888-react_cxvntpmhfqwskjwv-WyVQ' \
        --header 'quora-canary-revision: false' \
        --header 'quora-formkey: 70f70e719f28a1fb89ee3c1014bc2b35' \
        --header 'quora-page-creation-time: 1727150155427358' \
        --header 'quora-revision: 34fdbab78dffb8359989920976565945ef13f659' \
        --header 'quora-window-id: react_cxvntpmhfqwskjwv' \
        --header 'referer: https://shopifyexpert1.quora.com/' \
        --header 'referrer-policy: strict-origin-when-cross-origin' \
        --header 'sec-ch-ua: "Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"' \
        --header 'sec-ch-ua-mobile: ?1' \
        --header 'sec-ch-ua-platform: "Android"' \
        --header 'sec-fetch-dest: empty' \
        --header 'sec-fetch-mode: cors' \
        --header 'sec-fetch-site: same-origin' \
        --header 'user-agent: Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Mobile Safari/537.36' \
        --data '{"queryName":"TribeFollowersSocialFirstPagedListQuery","variables":{"tribeId":3987924,"first":10,"after":\"""" + str(index) + """\","permissions":["follower"],"socialFirst":true},"extensions":{"hash":"4157978ce838c8661e0cc1eb8b9b179b186c26e24c01858f7098f950a615d6a6"}}'
                """

        # Runs curl command in python subprocess (NOTE: Cannot use python requests - it breaks the request)
        p = subprocess.Popen(curl_command, shell=True, executable='/bin/bash' ,stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        output, status = p.communicate()

        # Saves user data to data_to_return dict 
        json_response = json.loads(output)
        list_of_nodes = json_response.get("data", {}).get("tribe", {}).get("tribeFollowersSocialFirstConnection", {}).get("edges", [])
        for node in list_of_nodes:
            node_data = node.get("node", {})
            print("This is the node", node_data)
    
            user_info = node_data.get("user", {})
            user_id = user_info.get("uid", 0)
            is_anon = user_info.get("isAnon", False)
            follower_count = user_info.get("followerCount", 0)
            temp_dict = {
                "user_id": user_id,
                "is_anon": "1" if is_anon else "0",
                "follower_count": follower_count
            }
            data_to_return.append(temp_dict)

        if index >= limit:
            is_valid_operation = False 
            break
        index += 1

    
    # Saves all users to quora_users.xlsx - This excel file will be passed into the main function to dispatch follower requests 
    df = pd.DataFrame(data_to_return)
    df.to_excel('quora_users.xlsx', index=True)

    return data_to_return


scrape_users("")
# Out:
# This is the url
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDoxMzc1NDE0Nw==', '__typename': 'TribeUser', 'user': {'uid': 13754147, '__typename': 'User', 'id': 'VXNlckAwOjEzNzU0MTQ3', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-13754147-200-4AeST38Iw1v7I487wTOE9Jov1Diw2xH1.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Matthew-Butterworth-2', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MTM3NTQxNDc6TEFUTg==', 'reverseOrder': False, 'givenName': 'Matthew', 'familyName': 'Butterworth', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 13, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDo5Nzc1NzI3OQ==', 'credentialId': 97757279, 'translatedString': 'Marketing Director'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 13754147, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDoyNDk1MDkxNg==', '__typename': 'TribeUser', 'user': {'uid': 24950916, '__typename': 'User', 'id': 'VXNlckAwOjI0OTUwOTE2', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-24950916-200-yupogmckekymtlfdzudwsmvxvnsaqtaf.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Marco-Belcastro-Bara', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MjQ5NTA5MTY6TEFUTg==', 'reverseOrder': False, 'givenName': 'Marco', 'familyName': 'Belcastro-Bara', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1607, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'TribeCredential', '__isCredential': 'TribeCredential', 'id': 'VHJpYmVDcmVkZW50aWFsQDA6MTQ4Mjc4MTA4', 'credentialId': 148278108, 'translatedString': 'BDSM Relationships. Master.'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 24950916, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozMTM3Nzk5OQ==', '__typename': 'TribeUser', 'user': {'uid': 31377999, '__typename': 'User', 'id': 'VXNlckAwOjMxMzc3OTk5', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-31377999-200-jslzfeiaxpdkspfytlxtegutxrrargod.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Einer-Durango', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzEzNzc5OTk6TEFUTg==', 'reverseOrder': False, 'givenName': 'Einer', 'familyName': 'Durango', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 3, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'FreeFormCredential', '__isCredential': 'FreeFormCredential', 'id': 'RnJlZUZvcm1DcmVkZW50aWFsQDA6MTUzMDA4MTc=', 'credentialId': 15300817, 'translatedString': 'Pharmacist'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 31377999, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozNTk1ODYyNw==', '__typename': 'TribeUser', 'user': {'uid': 35958627, '__typename': 'User', 'id': 'VXNlckAwOjM1OTU4NjI3', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-35958627-200-rmnmwokjiokxgnjulohjtcfduciybpmk.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Womanlywhispers', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzU5NTg2Mjc6TEFUTg==', 'reverseOrder': False, 'givenName': 'Womanlywhispers', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 49, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'FreeFormCredential', '__isCredential': 'FreeFormCredential', 'id': 'RnJlZUZvcm1DcmVkZW50aWFsQDA6MTYwMTY0MTM3', 'credentialId': 160164137, 'translatedString': 'Expert Relationship Guidance & Positivity Coach'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 35958627, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTMwODcwMw==', '__typename': 'TribeUser', 'user': {'uid': 39308703, '__typename': 'User', 'id': 'VXNlckAwOjM5MzA4NzAz', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39308703-200-sqacfbbmxwsyegnsrgnvuvnqfbmspdie.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Tatiana-Mathis', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzkzMDg3MDM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Tatiana', 'familyName': 'Mathis', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 71, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxODYzOTUyOA==', 'credentialId': 18639528, 'translatedString': 'CEO and Co-founder at Comm Geeks LLC (2017-present)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39308703, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTQ4MDM1MA==', '__typename': 'TribeUser', 'user': {'uid': 39480350, '__typename': 'User', 'id': 'VXNlckAwOjM5NDgwMzUw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39480350-200-doicsktjwxqlsajoqajqvoefvotswhzg.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Lynne-340', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk0ODAzNTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Lynne', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 146, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNDg3NjAyNjY=', 'credentialId': 148760266, 'translatedString': 'worked at JPMorgan Chase (2018-2021)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39480350, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTc0ODkzMg==', '__typename': 'TribeUser', 'user': {'uid': 39748932, '__typename': 'User', 'id': 'VXNlckAwOjM5NzQ4OTMy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39748932-200-buxhvqjwpjplziyueaqrdyhspyhcaluv.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Yasmin-1793', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk3NDg5MzI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Yasmin', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 157, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNjgzOTg5MTU=', 'credentialId': 168398915, 'translatedString': 'former Teacher'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39748932, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0Mzg4NzM1Mw==', '__typename': 'TribeUser', 'user': {'uid': 43887353, '__typename': 'User', 'id': 'VXNlckAwOjQzODg3MzUz', 'isAnon': False, 'profileImageUrl': 'https://qsf.cf2.quoracdn.net/-4-images.new_grid.profile_default.png-26-688c79556f251aa0.png', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Andrew-Manero', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDM4ODczNTM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Andrew', 'familyName': 'Manero', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': None, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 43887353, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0NDA2NTUxMA==', '__typename': 'TribeUser', 'user': {'uid': 44065510, '__typename': 'User', 'id': 'VXNlckAwOjQ0MDY1NTEw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-44065510-200-iyhxacsgjjvlcnnenljmqgiysoljhrdc.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Jan-Li-52', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDQwNjU1MTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Jan Li', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'LanguageCredential', '__isCredential': 'LanguageCredential', 'id': 'TGFuZ3VhZ2VDcmVkZW50aWFsQDA6MTgxNTY5MDIx', 'credentialId': 181569021, 'translatedString': 'knows Chinese'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 44065510, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo2NTQwODA1Mg==', '__typename': 'TribeUser', 'user': {'uid': 65408052, '__typename': 'User', 'id': 'VXNlckAwOjY1NDA4MDUy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-65408052-200-ibldnzejnzlunndujgdlbsaauwssjynr.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Zexiang-Lee', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NjU0MDgwNTI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Zexiang', 'familyName': 'Lee', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 17, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'SchoolCredential', '__isCredential': 'SchoolCredential', 'id': 'U2Nob29sQ3JlZGVudGlhbEAwOjMxNjcwNDQz', 'credentialId': 31670443, 'translatedString': 'studied at Huazhong University of Science and Technology'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 65408052, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDoyNDk1MDkxNg==', '__typename': 'TribeUser', 'user': {'uid': 24950916, '__typename': 'User', 'id': 'VXNlckAwOjI0OTUwOTE2', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-24950916-200-yupogmckekymtlfdzudwsmvxvnsaqtaf.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Marco-Belcastro-Bara', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MjQ5NTA5MTY6TEFUTg==', 'reverseOrder': False, 'givenName': 'Marco', 'familyName': 'Belcastro-Bara', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1607, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'TribeCredential', '__isCredential': 'TribeCredential', 'id': 'VHJpYmVDcmVkZW50aWFsQDA6MTQ4Mjc4MTA4', 'credentialId': 148278108, 'translatedString': 'BDSM Relationships. Master.'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 24950916, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozMTM3Nzk5OQ==', '__typename': 'TribeUser', 'user': {'uid': 31377999, '__typename': 'User', 'id': 'VXNlckAwOjMxMzc3OTk5', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-31377999-200-jslzfeiaxpdkspfytlxtegutxrrargod.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Einer-Durango', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzEzNzc5OTk6TEFUTg==', 'reverseOrder': False, 'givenName': 'Einer', 'familyName': 'Durango', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 3, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'FreeFormCredential', '__isCredential': 'FreeFormCredential', 'id': 'RnJlZUZvcm1DcmVkZW50aWFsQDA6MTUzMDA4MTc=', 'credentialId': 15300817, 'translatedString': 'Pharmacist'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 31377999, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozNTk1ODYyNw==', '__typename': 'TribeUser', 'user': {'uid': 35958627, '__typename': 'User', 'id': 'VXNlckAwOjM1OTU4NjI3', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-35958627-200-rmnmwokjiokxgnjulohjtcfduciybpmk.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Womanlywhispers', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzU5NTg2Mjc6TEFUTg==', 'reverseOrder': False, 'givenName': 'Womanlywhispers', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 49, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'FreeFormCredential', '__isCredential': 'FreeFormCredential', 'id': 'RnJlZUZvcm1DcmVkZW50aWFsQDA6MTYwMTY0MTM3', 'credentialId': 160164137, 'translatedString': 'Expert Relationship Guidance & Positivity Coach'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 35958627, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTMwODcwMw==', '__typename': 'TribeUser', 'user': {'uid': 39308703, '__typename': 'User', 'id': 'VXNlckAwOjM5MzA4NzAz', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39308703-200-sqacfbbmxwsyegnsrgnvuvnqfbmspdie.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Tatiana-Mathis', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzkzMDg3MDM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Tatiana', 'familyName': 'Mathis', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 71, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxODYzOTUyOA==', 'credentialId': 18639528, 'translatedString': 'CEO and Co-founder at Comm Geeks LLC (2017-present)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39308703, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTQ4MDM1MA==', '__typename': 'TribeUser', 'user': {'uid': 39480350, '__typename': 'User', 'id': 'VXNlckAwOjM5NDgwMzUw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39480350-200-doicsktjwxqlsajoqajqvoefvotswhzg.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Lynne-340', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk0ODAzNTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Lynne', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 146, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNDg3NjAyNjY=', 'credentialId': 148760266, 'translatedString': 'worked at JPMorgan Chase (2018-2021)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39480350, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTc0ODkzMg==', '__typename': 'TribeUser', 'user': {'uid': 39748932, '__typename': 'User', 'id': 'VXNlckAwOjM5NzQ4OTMy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39748932-200-buxhvqjwpjplziyueaqrdyhspyhcaluv.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Yasmin-1793', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk3NDg5MzI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Yasmin', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 157, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNjgzOTg5MTU=', 'credentialId': 168398915, 'translatedString': 'former Teacher'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39748932, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0Mzg4NzM1Mw==', '__typename': 'TribeUser', 'user': {'uid': 43887353, '__typename': 'User', 'id': 'VXNlckAwOjQzODg3MzUz', 'isAnon': False, 'profileImageUrl': 'https://qsf.cf2.quoracdn.net/-4-images.new_grid.profile_default.png-26-688c79556f251aa0.png', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Andrew-Manero', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDM4ODczNTM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Andrew', 'familyName': 'Manero', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': None, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 43887353, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0NDA2NTUxMA==', '__typename': 'TribeUser', 'user': {'uid': 44065510, '__typename': 'User', 'id': 'VXNlckAwOjQ0MDY1NTEw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-44065510-200-iyhxacsgjjvlcnnenljmqgiysoljhrdc.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Jan-Li-52', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDQwNjU1MTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Jan Li', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'LanguageCredential', '__isCredential': 'LanguageCredential', 'id': 'TGFuZ3VhZ2VDcmVkZW50aWFsQDA6MTgxNTY5MDIx', 'credentialId': 181569021, 'translatedString': 'knows Chinese'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 44065510, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo2NTQwODA1Mg==', '__typename': 'TribeUser', 'user': {'uid': 65408052, '__typename': 'User', 'id': 'VXNlckAwOjY1NDA4MDUy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-65408052-200-ibldnzejnzlunndujgdlbsaauwssjynr.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Zexiang-Lee', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NjU0MDgwNTI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Zexiang', 'familyName': 'Lee', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 17, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'SchoolCredential', '__isCredential': 'SchoolCredential', 'id': 'U2Nob29sQ3JlZGVudGlhbEAwOjMxNjcwNDQz', 'credentialId': 31670443, 'translatedString': 'studied at Huazhong University of Science and Technology'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 65408052, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo3MzQwMzg0MQ==', '__typename': 'TribeUser', 'user': {'uid': 73403841, '__typename': 'User', 'id': 'VXNlckAwOjczNDAzODQx', 'isAnon': False, 'profileImageUrl': 'https://qsf.cf2.quoracdn.net/-4-images.new_grid.profile_default.png-26-688c79556f251aa0.png', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Joseph-Diaz-13', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NzM0MDM4NDE6TEFUTg==', 'reverseOrder': False, 'givenName': 'Joseph', 'familyName': 'Diaz', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 2736, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': None, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 73403841, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozMTM3Nzk5OQ==', '__typename': 'TribeUser', 'user': {'uid': 31377999, '__typename': 'User', 'id': 'VXNlckAwOjMxMzc3OTk5', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-31377999-200-jslzfeiaxpdkspfytlxtegutxrrargod.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Einer-Durango', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzEzNzc5OTk6TEFUTg==', 'reverseOrder': False, 'givenName': 'Einer', 'familyName': 'Durango', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 3, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'FreeFormCredential', '__isCredential': 'FreeFormCredential', 'id': 'RnJlZUZvcm1DcmVkZW50aWFsQDA6MTUzMDA4MTc=', 'credentialId': 15300817, 'translatedString': 'Pharmacist'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 31377999, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozNTk1ODYyNw==', '__typename': 'TribeUser', 'user': {'uid': 35958627, '__typename': 'User', 'id': 'VXNlckAwOjM1OTU4NjI3', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-35958627-200-rmnmwokjiokxgnjulohjtcfduciybpmk.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Womanlywhispers', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzU5NTg2Mjc6TEFUTg==', 'reverseOrder': False, 'givenName': 'Womanlywhispers', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 49, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'FreeFormCredential', '__isCredential': 'FreeFormCredential', 'id': 'RnJlZUZvcm1DcmVkZW50aWFsQDA6MTYwMTY0MTM3', 'credentialId': 160164137, 'translatedString': 'Expert Relationship Guidance & Positivity Coach'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 35958627, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTMwODcwMw==', '__typename': 'TribeUser', 'user': {'uid': 39308703, '__typename': 'User', 'id': 'VXNlckAwOjM5MzA4NzAz', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39308703-200-sqacfbbmxwsyegnsrgnvuvnqfbmspdie.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Tatiana-Mathis', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6MzkzMDg3MDM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Tatiana', 'familyName': 'Mathis', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 71, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxODYzOTUyOA==', 'credentialId': 18639528, 'translatedString': 'CEO and Co-founder at Comm Geeks LLC (2017-present)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39308703, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTQ4MDM1MA==', '__typename': 'TribeUser', 'user': {'uid': 39480350, '__typename': 'User', 'id': 'VXNlckAwOjM5NDgwMzUw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39480350-200-doicsktjwxqlsajoqajqvoefvotswhzg.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Lynne-340', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk0ODAzNTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Lynne', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 146, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNDg3NjAyNjY=', 'credentialId': 148760266, 'translatedString': 'worked at JPMorgan Chase (2018-2021)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39480350, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTc0ODkzMg==', '__typename': 'TribeUser', 'user': {'uid': 39748932, '__typename': 'User', 'id': 'VXNlckAwOjM5NzQ4OTMy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39748932-200-buxhvqjwpjplziyueaqrdyhspyhcaluv.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Yasmin-1793', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk3NDg5MzI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Yasmin', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 157, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNjgzOTg5MTU=', 'credentialId': 168398915, 'translatedString': 'former Teacher'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39748932, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0Mzg4NzM1Mw==', '__typename': 'TribeUser', 'user': {'uid': 43887353, '__typename': 'User', 'id': 'VXNlckAwOjQzODg3MzUz', 'isAnon': False, 'profileImageUrl': 'https://qsf.cf2.quoracdn.net/-4-images.new_grid.profile_default.png-26-688c79556f251aa0.png', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Andrew-Manero', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDM4ODczNTM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Andrew', 'familyName': 'Manero', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': None, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 43887353, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0NDA2NTUxMA==', '__typename': 'TribeUser', 'user': {'uid': 44065510, '__typename': 'User', 'id': 'VXNlckAwOjQ0MDY1NTEw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-44065510-200-iyhxacsgjjvlcnnenljmqgiysoljhrdc.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Jan-Li-52', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDQwNjU1MTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Jan Li', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'LanguageCredential', '__isCredential': 'LanguageCredential', 'id': 'TGFuZ3VhZ2VDcmVkZW50aWFsQDA6MTgxNTY5MDIx', 'credentialId': 181569021, 'translatedString': 'knows Chinese'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 44065510, 'tribeId': 3987924, 'isDirectSubscriber': False}
# ...
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDozOTc0ODkzMg==', '__typename': 'TribeUser', 'user': {'uid': 39748932, '__typename': 'User', 'id': 'VXNlckAwOjM5NzQ4OTMy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-39748932-200-buxhvqjwpjplziyueaqrdyhspyhcaluv.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Yasmin-1793', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6Mzk3NDg5MzI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Yasmin', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 157, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxNjgzOTg5MTU=', 'credentialId': 168398915, 'translatedString': 'former Teacher'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 39748932, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0Mzg4NzM1Mw==', '__typename': 'TribeUser', 'user': {'uid': 43887353, '__typename': 'User', 'id': 'VXNlckAwOjQzODg3MzUz', 'isAnon': False, 'profileImageUrl': 'https://qsf.cf2.quoracdn.net/-4-images.new_grid.profile_default.png-26-688c79556f251aa0.png', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Andrew-Manero', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDM4ODczNTM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Andrew', 'familyName': 'Manero', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': None, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 43887353, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo0NDA2NTUxMA==', '__typename': 'TribeUser', 'user': {'uid': 44065510, '__typename': 'User', 'id': 'VXNlckAwOjQ0MDY1NTEw', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-44065510-200-iyhxacsgjjvlcnnenljmqgiysoljhrdc.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Jan-Li-52', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NDQwNjU1MTA6TEFUTg==', 'reverseOrder': False, 'givenName': 'Jan Li', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 1, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'LanguageCredential', '__isCredential': 'LanguageCredential', 'id': 'TGFuZ3VhZ2VDcmVkZW50aWFsQDA6MTgxNTY5MDIx', 'credentialId': 181569021, 'translatedString': 'knows Chinese'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 44065510, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo2NTQwODA1Mg==', '__typename': 'TribeUser', 'user': {'uid': 65408052, '__typename': 'User', 'id': 'VXNlckAwOjY1NDA4MDUy', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-65408052-200-ibldnzejnzlunndujgdlbsaauwssjynr.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Zexiang-Lee', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NjU0MDgwNTI6TEFUTg==', 'reverseOrder': False, 'givenName': 'Zexiang', 'familyName': 'Lee', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 17, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'SchoolCredential', '__isCredential': 'SchoolCredential', 'id': 'U2Nob29sQ3JlZGVudGlhbEAwOjMxNjcwNDQz', 'credentialId': 31670443, 'translatedString': 'studied at Huazhong University of Science and Technology'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 65408052, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo3MzQwMzg0MQ==', '__typename': 'TribeUser', 'user': {'uid': 73403841, '__typename': 'User', 'id': 'VXNlckAwOjczNDAzODQx', 'isAnon': False, 'profileImageUrl': 'https://qsf.cf2.quoracdn.net/-4-images.new_grid.profile_default.png-26-688c79556f251aa0.png', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Joseph-Diaz-13', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6NzM0MDM4NDE6TEFUTg==', 'reverseOrder': False, 'givenName': 'Joseph', 'familyName': 'Diaz', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 2736, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': None, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 73403841, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo4MjI0MjQzNA==', '__typename': 'TribeUser', 'user': {'uid': 82242434, '__typename': 'User', 'id': 'VXNlckAwOjgyMjQyNDM0', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-82242434-200-gbwqyekuaelgtcvgiikopcckakktkfqv.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': False, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Drula', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6ODIyNDI0MzQ6TEFUTg==', 'reverseOrder': False, 'givenName': 'Drula', 'familyName': '', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 2845, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDo1OTY1MzYy', 'credentialId': 5965362, 'translatedString': 'works at Freelancing'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 82242434, 'tribeId': 3987924, 'isDirectSubscriber': False}
# This is the node {'id': 'VHJpYmVVc2VyQDA6Mzk4NzkyNDo4Mjg3ODY4Mw==', '__typename': 'TribeUser', 'user': {'uid': 82878683, '__typename': 'User', 'id': 'VXNlckAwOjgyODc4Njgz', 'isAnon': False, 'profileImageUrl': 'https://qph.cf2.quoracdn.net/main-thumb-82878683-200-alltlgdvfiviwryxvaolvxsbmfxeqmwz.jpeg', 'isVerified': False, 'businessStatus': None, 'consumerBundleActive': True, 'isMachineAnswerBot': False, 'profileUrl': 'https://www.quora.com/profile/Rohitashva-Singhvi', 'useTranslatedName': False, 'names': [{'__typename': 'UserName', 'id': 'VXNlck5hbWU6ODI4Nzg2ODM6TEFUTg==', 'reverseOrder': False, 'givenName': 'Rohitashva', 'familyName': 'Singhvi', 'scriptCode': 'LATN'}], 'adminNames': [], 'isBlocking': False, 'isBlockedByViewer': False, 'viewerIsFollowing': False, 'followerCount': 2862, 'viewerIsFollowedBy': False}, 'tribe': {'owner': None, 'tribeId': 3987924, 'nameString': 'Shopify Expert !', 'isFollowing': True, 'viewerCredential': None, 'viewer': {'user': {'uid': 228910367, 'id': 'VXNlckAwOjIyODkxMDM2Nw=='}, 'id': 'Vmlld2VyQDA6MA=='}, 'id': 'VHJpYmVAMDozOTg3OTI0', '__typename': 'Tribe'}, 'isInvitedToTransferOwnership': False, 'numItemsLastWeek': 0, 'numViewsLastWeek': 0, 'numUpvotesLastWeek': 0, 'numItemsLastMonth': 0, 'permission': 1, 'isBlockedByTribe': False, 'credentialWithDefault': {'__typename': 'WorkCredential', '__isCredential': 'WorkCredential', 'id': 'V29ya0NyZWRlbnRpYWxAMDoxODA4MTEwODY=', 'credentialId': 180811086, 'translatedString': 'Writing & Blogging at I Am My Own Boss (2017-present)'}, 'permissionsViewerCanInviteTo': [], 'permissionsViewerCanChangeTo': [], 'permissionsInvitedByViewer': [], 'viewerCanBlockTribeUser': False, 'viewerShouldSeeTransferOwnershipItem': False, 'uid': 82878683, 'tribeId': 3987924, 'isDirectSubscriber': False}
# [{'user_id': 13754147, 'is_anon': '0', 'follower_count': 13},
#  {'user_id': 24950916, 'is_anon': '0', 'follower_count': 1607},
#  {'user_id': 31377999, 'is_anon': '0', 'follower_count': 3},
#  {'user_id': 35958627, 'is_anon': '0', 'follower_count': 49},
#  {'user_id': 39308703, 'is_anon': '0', 'follower_count': 71},
#  {'user_id': 39480350, 'is_anon': '0', 'follower_count': 146},
#  {'user_id': 39748932, 'is_anon': '0', 'follower_count': 157},
#  {'user_id': 43887353, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 44065510, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 65408052, 'is_anon': '0', 'follower_count': 17},
#  {'user_id': 24950916, 'is_anon': '0', 'follower_count': 1607},
#  {'user_id': 31377999, 'is_anon': '0', 'follower_count': 3},
#  {'user_id': 35958627, 'is_anon': '0', 'follower_count': 49},
#  {'user_id': 39308703, 'is_anon': '0', 'follower_count': 71},
#  {'user_id': 39480350, 'is_anon': '0', 'follower_count': 146},
#  {'user_id': 39748932, 'is_anon': '0', 'follower_count': 157},
#  {'user_id': 43887353, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 44065510, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 65408052, 'is_anon': '0', 'follower_count': 17},
#  {'user_id': 73403841, 'is_anon': '0', 'follower_count': 2736},
#  {'user_id': 31377999, 'is_anon': '0', 'follower_count': 3},
#  {'user_id': 35958627, 'is_anon': '0', 'follower_count': 49},
#  {'user_id': 39308703, 'is_anon': '0', 'follower_count': 71},
#  {'user_id': 39480350, 'is_anon': '0', 'follower_count': 146},
#  {'user_id': 39748932, 'is_anon': '0', 'follower_count': 157},
#  {'user_id': 43887353, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 44065510, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 65408052, 'is_anon': '0', 'follower_count': 17},
#  {'user_id': 73403841, 'is_anon': '0', 'follower_count': 2736},
#  {'user_id': 82242434, 'is_anon': '0', 'follower_count': 2845},
#  {'user_id': 35958627, 'is_anon': '0', 'follower_count': 49},
#  {'user_id': 39308703, 'is_anon': '0', 'follower_count': 71},
#  {'user_id': 39480350, 'is_anon': '0', 'follower_count': 146},
#  {'user_id': 39748932, 'is_anon': '0', 'follower_count': 157},
#  {'user_id': 43887353, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 44065510, 'is_anon': '0', 'follower_count': 1},
#  {'user_id': 65408052, 'is_anon': '0', 'follower_count': 17},
#  {'user_id': 73403841, 'is_anon': '0', 'follower_count': 2736},
#  {'user_id': 82242434, 'is_anon': '0', 'follower_count': 2845},
#  {'user_id': 82878683, 'is_anon': '0', 'follower_count': 2862}]
